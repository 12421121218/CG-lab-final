# %% [markdown]
# <a href="https://colab.research.google.com/github/12421121218/CG-lab-final/blob/main/Mid_point_Circle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math

def midpoint_circle(xc, yc, r):
    points = []
    x = 0
    y = r
    p = 1 - r   # Initial decision parameter

    def plot_circle_points(xc, yc, x, y):
        pts = [
            (xc + x, yc + y),
            (xc - x, yc + y),
            (xc + x, yc - y),
            (xc - x, yc - y),
            (xc + y, yc + x),
            (xc - y, yc + x),
            (xc + y, yc - x),
            (xc - y, yc - x),
        ]
        for px, py in pts:
            if (px, py) not in points:
                points.append((float(f"{px:.2f}"), float(f"{py:.2f}")))

    while x <= y:
        plot_circle_points(xc, yc, x, y)
        if p < 0:
            p += 2 * x + 3
        else:
            p += 2 * (x - y) + 5
            y -= 1
        x += 1

    return points

xc, yc = 0, 0
r = 2

points = midpoint_circle(xc, yc, r)

print("Calculated Points (Mid-Point Circle Drawing):")
for p in points:
    print(p)
points_sorted = sorted(points, key=lambda p: math.atan2(p[1] - yc, p[0] - xc))
plt.figure(figsize=(7,7))
x_vals = [p[0] for p in points_sorted]
y_vals = [p[1] for p in points_sorted]

x_vals.append(x_vals[0])
y_vals.append(y_vals[0])

plt.plot(x_vals, y_vals, marker='o', color='green')

for i, (x, y) in enumerate(points_sorted):
    label = f"P{i}({x},{y})"
    plt.text(x + 0.1, y + 0.1, label, fontsize=8)

plt.title("Mid-Point Circle Drawing Algorithm")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# Calculated Points (Mid-Point Circle Drawing):
# (0.0, 2.0)
# (0.0, -2.0)
# (2.0, 0.0)
# (-2.0, 0.0)
# (1.0, 2.0)
# (-1.0, 2.0)
# (1.0, -2.0)
# (-1.0, -2.0)
# (2.0, 1.0)
# (-2.0, 1.0)
# (2.0, -1.0)
# (-2.0, -1.0)
